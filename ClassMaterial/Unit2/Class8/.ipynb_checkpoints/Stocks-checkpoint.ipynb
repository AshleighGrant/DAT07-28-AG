# %%
import pandas as pd
import numpy as np

# %%
cd /Users/imac/DAT07-28-AG/ClassMaterial/Unit2/Data
# Out:
# /Users/imac/DAT07-28-AG/ClassMaterial/Unit2/Data

# %%
stocks = pd.read_csv("stocks.csv", parse_dates=['Date'])

# %%
stocks = stocks.set_index(['Date']).sort_index(level=0)

# %%
stocks
# Out:
#                   AAPL        GOOGL          FB        MSFT         AMZN
# Date
# 2014-11-05  108.860001   555.950012   74.830002   47.860001   296.519989
# 2014-11-06  108.699997   551.690002   75.260002   48.700001   296.640015
# 2014-11-07  109.010002   551.820007   75.599998   48.680000   299.859985
# 2014-11-10  108.830002   558.229980   75.000000   48.889999   305.109985
# 2014-11-11  109.699997   561.289978   74.610001   48.869999   312.010010
# ...                ...          ...         ...         ...          ...
# 2019-10-28  249.050003  1288.979980  189.399994  144.190002  1777.079956
# 2019-10-29  243.289993  1260.660034  189.309998  142.830002  1762.709961
# 2019-10-30  243.259995  1260.699951  188.250000  144.610001  1779.989990
# 2019-10-31  248.759995  1258.800049  191.649994  143.369995  1776.660034
# 2019-11-01  255.820007  1272.250000  193.619995  143.720001  1791.439941
#
# [1257 rows x 5 columns]

# %%
stocks.shift()
# Out:
#                   AAPL        GOOGL          FB        MSFT         AMZN
# Date
# 2014-11-05         NaN          NaN         NaN         NaN          NaN
# 2014-11-06  108.860001   555.950012   74.830002   47.860001   296.519989
# 2014-11-07  108.699997   551.690002   75.260002   48.700001   296.640015
# 2014-11-10  109.010002   551.820007   75.599998   48.680000   299.859985
# 2014-11-11  108.830002   558.229980   75.000000   48.889999   305.109985
# ...                ...          ...         ...         ...          ...
# 2019-10-28  246.580002  1264.300049  187.889999  140.729996  1761.329956
# 2019-10-29  249.050003  1288.979980  189.399994  144.190002  1777.079956
# 2019-10-30  243.289993  1260.660034  189.309998  142.830002  1762.709961
# 2019-10-31  243.259995  1260.699951  188.250000  144.610001  1779.989990
# 2019-11-01  248.759995  1258.800049  191.649994  143.369995  1776.660034
#
# [1257 rows x 5 columns]

# %%
(stocks / stocks.shift()).head()
# Out:
#                 AAPL     GOOGL        FB      MSFT      AMZN
# Date
# 2014-11-05       NaN       NaN       NaN       NaN       NaN
# 2014-11-06  0.998530  0.992337  1.005746  1.017551  1.000405
# 2014-11-07  1.002852  1.000236  1.004518  0.999589  1.010855
# 2014-11-10  0.998349  1.011616  0.992064  1.004314  1.017508
# 2014-11-11  1.007994  1.005482  0.994800  0.999591  1.022615

# %%
(stocks / stocks.shift()).cumprod().head()
# Out:
#                 AAPL     GOOGL        FB      MSFT      AMZN
# Date
# 2014-11-05       NaN       NaN       NaN       NaN       NaN
# 2014-11-06  0.998530  0.992337  1.005746  1.017551  1.000405
# 2014-11-07  1.001378  0.992571  1.010290  1.017133  1.011264
# 2014-11-10  0.999724  1.004101  1.002272  1.021521  1.028969
# 2014-11-11  1.007716  1.009605  0.997060  1.021103  1.052239

# %%
((stocks / stocks.shift()).cumprod()).plot()

# %%
stocks.pct_change()
# Out:
#                 AAPL     GOOGL        FB      MSFT      AMZN
# Date
# 2014-11-05       NaN       NaN       NaN       NaN       NaN
# 2014-11-06 -0.001470 -0.007663  0.005746  0.017551  0.000405
# 2014-11-07  0.002852  0.000236  0.004518 -0.000411  0.010855
# 2014-11-10 -0.001651  0.011616 -0.007936  0.004314  0.017508
# 2014-11-11  0.007994  0.005482 -0.005200 -0.000409  0.022615
# ...              ...       ...       ...       ...       ...
# 2019-10-28  0.010017  0.019521  0.008037  0.024586  0.008942
# 2019-10-29 -0.023128 -0.021971 -0.000475 -0.009432 -0.008086
# 2019-10-30 -0.000123  0.000032 -0.005599  0.012462  0.009803
# 2019-10-31  0.022610 -0.001507  0.018061 -0.008575 -0.001871
# 2019-11-01  0.028381  0.010685  0.010279  0.002441  0.008319
#
# [1257 rows x 5 columns]

# %%
one_week = pd.DateOffset(weeks=1)

# %%
one_week
# Out:
# <DateOffset: weeks=1>

# %%
stocks.index
# Out:
# Index(['2014-11-05', '2014-11-06', '2014-11-07', '2014-11-10', '2014-11-11',
#        '2014-11-12', '2014-11-13', '2014-11-14', '2014-11-17', '2014-11-18',
#        ...
#        '2019-10-21', '2019-10-22', '2019-10-23', '2019-10-24', '2019-10-25',
#        '2019-10-28', '2019-10-29', '2019-10-30', '2019-10-31', '2019-11-01'],
#       dtype='object', name='Date', length=1257)

# %%
stocks.index - one_week
# Out:
# DatetimeIndex(['2014-10-29', '2014-10-30', '2014-10-31', '2014-11-03',
#                '2014-11-04', '2014-11-05', '2014-11-06', '2014-11-07',
#                '2014-11-10', '2014-11-11',
#                ...
#                '2019-10-14', '2019-10-15', '2019-10-16', '2019-10-17',
#                '2019-10-18', '2019-10-21', '2019-10-22', '2019-10-23',
#                '2019-10-24', '2019-10-25'],
#               dtype='datetime64[ns]', name='Date', length=1257, freq=None)

# %%
stocks.shift(1, freq=one_week)
# Out:
#                   AAPL        GOOGL          FB        MSFT         AMZN
# Date
# 2014-11-12  108.860001   555.950012   74.830002   47.860001   296.519989
# 2014-11-13  108.699997   551.690002   75.260002   48.700001   296.640015
# 2014-11-14  109.010002   551.820007   75.599998   48.680000   299.859985
# 2014-11-17  108.830002   558.229980   75.000000   48.889999   305.109985
# 2014-11-18  109.699997   561.289978   74.610001   48.869999   312.010010
# ...                ...          ...         ...         ...          ...
# 2019-11-04  249.050003  1288.979980  189.399994  144.190002  1777.079956
# 2019-11-05  243.289993  1260.660034  189.309998  142.830002  1762.709961
# 2019-11-06  243.259995  1260.699951  188.250000  144.610001  1779.989990
# 2019-11-07  248.759995  1258.800049  191.649994  143.369995  1776.660034
# 2019-11-08  255.820007  1272.250000  193.619995  143.720001  1791.439941
#
# [1257 rows x 5 columns]

# %%
stocks.groupby("Date")[["AMZN"]].mean()
# Out:
#                    AMZN
# Date
# 2014-11-05   296.519989
# 2014-11-06   296.640015
# 2014-11-07   299.859985
# 2014-11-10   305.109985
# 2014-11-11   312.010010
# ...                 ...
# 2019-10-28  1777.079956
# 2019-10-29  1762.709961
# 2019-10-30  1779.989990
# 2019-10-31  1776.660034
# 2019-11-01  1791.439941
#
# [1257 rows x 1 columns]

# %%
stocks.index.year
# Out:
# Int64Index([2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014,
#             ...
#             2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019],
#            dtype='int64', name='Date', length=1257)

# %%
type(stocks.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
stocks.index
# Out:
# DatetimeIndex(['2014-11-05', '2014-11-06', '2014-11-07', '2014-11-10',
#                '2014-11-11', '2014-11-12', '2014-11-13', '2014-11-14',
#                '2014-11-17', '2014-11-18',
#                ...
#                '2019-10-21', '2019-10-22', '2019-10-23', '2019-10-24',
#                '2019-10-25', '2019-10-28', '2019-10-29', '2019-10-30',
#                '2019-10-31', '2019-11-01'],
#               dtype='datetime64[ns]', name='Date', length=1257, freq=None)

# %%
panel_data = pd.read_csv("../data/stocks_panel.csv", parse_dates=["Date"])

# %%
panel_data
# Out:
#            Date  Stock        Price
# 0    2014-11-05   AAPL   108.860001
# 1    2014-11-05   AMZN   296.519989
# 2    2014-11-05     FB    74.830002
# 3    2014-11-05   MSFT    47.860001
# 4    2014-11-05  GOOGL   555.950012
# ...         ...    ...          ...
# 6280 2019-11-01     FB   193.619995
# 6281 2019-11-01  GOOGL  1272.250000
# 6282 2019-11-01   AAPL   255.820007
# 6283 2019-11-01   MSFT   143.720001
# 6284 2019-11-01   AMZN  1791.439941
#
# [6285 rows x 3 columns]

# %%
panel_data.set_index(["Stock", "Date"])
# Out:
#                         Price
# Stock Date
# AAPL  2014-11-05   108.860001
# AMZN  2014-11-05   296.519989
# FB    2014-11-05    74.830002
# MSFT  2014-11-05    47.860001
# GOOGL 2014-11-05   555.950012
# ...                       ...
# FB    2019-11-01   193.619995
# GOOGL 2019-11-01  1272.250000
# AAPL  2019-11-01   255.820007
# MSFT  2019-11-01   143.720001
# AMZN  2019-11-01  1791.439941
#
# [6285 rows x 1 columns]

# %%
panel_data = panel_data.set_index(["Stock", "Date"]).sort_index(level=0)

# %%
panel_data
# Out:
#                        Price
# Stock Date
# AAPL  2014-11-05  108.860001
#       2014-11-06  108.699997
#       2014-11-07  109.010002
#       2014-11-10  108.830002
#       2014-11-11  109.699997
# ...                      ...
# MSFT  2019-10-28  144.190002
#       2019-10-29  142.830002
#       2019-10-30  144.610001
#       2019-10-31  143.369995
#       2019-11-01  143.720001
#
# [6285 rows x 1 columns]

# %%
panel_data.shift()
# Out:
#                        Price
# Stock Date
# AAPL  2014-11-05         NaN
#       2014-11-06  108.860001
#       2014-11-07  108.699997
#       2014-11-10  109.010002
#       2014-11-11  108.830002
# ...                      ...
# MSFT  2019-10-28  140.729996
#       2019-10-29  144.190002
#       2019-10-30  142.830002
#       2019-10-31  144.610001
#       2019-11-01  143.369995
#
# [6285 rows x 1 columns]

# %%
panel_data["Price"].mean(level=0)
# Out:
# Stock
# AAPL      149.512617
# AMZN     1069.032395
# FB        139.225958
# GOOGL     902.415203
# MSFT       77.800096
# Name: Price, dtype: float64

# %%
panel_data["Price"].shift(level=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-4ba86cc9ceb8> in <module>
# ----> 1 panel_data["Price"].shift(level=0)
#
# TypeError: shift() got an unexpected keyword argument 'level'

# %%
panel_data.groupby(level=0)["Price"].shift()
# Out:
# Stock  Date
# AAPL   2014-11-05           NaN
#        2014-11-06    108.860001
#        2014-11-07    108.699997
#        2014-11-10    109.010002
#        2014-11-11    108.830002
#                         ...
# MSFT   2019-10-28    140.729996
#        2019-10-29    144.190002
#        2019-10-30    142.830002
#        2019-10-31    144.610001
#        2019-11-01    143.369995
# Name: Price, Length: 6285, dtype: float64

# %%
panel_data.groupby(level=0)["Price"].shift(4).loc["MSFT"]
# Out:
# Date
# 2014-11-05           NaN
# 2014-11-06           NaN
# 2014-11-07           NaN
# 2014-11-10           NaN
# 2014-11-11     47.860001
#                  ...
# 2019-10-28    136.369995
# 2019-10-29    137.240005
# 2019-10-30    139.940002
# 2019-10-31    140.729996
# 2019-11-01    144.190002
# Name: Price, Length: 1257, dtype: float64

# %%
panel_data["Price"].shift(4).loc["MSFT"]
# Out:
# Date
# 2014-11-05    1260.660034
# 2014-11-06    1260.699951
# 2014-11-07    1258.800049
# 2014-11-10    1272.250000
# 2014-11-11      47.860001
#                  ...
# 2019-10-28     136.369995
# 2019-10-29     137.240005
# 2019-10-30     139.940002
# 2019-10-31     140.729996
# 2019-11-01     144.190002
# Name: Price, Length: 1257, dtype: float64
